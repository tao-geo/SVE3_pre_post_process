# %%
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

# %%
depth_list = [65, 60, 50, 40, 30, 20, 10, 1]
for depth_id in depth_list:
    visc = np.loadtxt(f'case_B_ICE1_VE300_VertAve1/out.map_visc.{depth_id}.1')

    plt.figure(figsize=(10,10))
    ax = plt.axes(projection=ccrs.PlateCarree())
    ax.coastlines()

    c = ax.scatter(visc[:,0], visc[:,1], c=np.log10(visc[:,2]), s=1)
    plt.colorbar(c, orientation='horizontal', label='log10(viscosity) [Pa.s]')
    plt.title(f"layer {depth_id}")
    plt.show()
